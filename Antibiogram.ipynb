# %% [markdown]
# <a href="https://colab.research.google.com/github/romenmeitei/Coexistence-of-Outermembrane-protein-A-and-Ade-efflux-pump-genes-in-Acinetobacter-baumanni-/blob/main/Antibiogram.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install matplotlib pandas seaborn

# %%
# Plot heatmap
plt.figure(figsize=(10, 6))

# Use `heatmap_data` for the heatmap and annotations
sns.heatmap(
    heatmap_data,
    annot=heatmap_data,  # Pass the same data as annotations
    fmt='',
    cmap="coolwarm",
    cbar_kws={'label': 'Resistance (R=1, S=0)'}
)

# Add italicized title and axis labels
plt.title("Antibiotic Resistance Profile of A. baumannii Isolates", fontdict={'fontstyle': 'italic'})
plt.xlabel("Isolate")
plt.ylabel("Antibiotic Class")

# Rotate x-axis and y-axis labels for better visibility
plt.xticks(rotation=45)
plt.yticks(rotation=0)

# Adjust layout
plt.tight_layout()

# Display the plot
plt.show()

# %%
# Plot heatmap
plt.figure(figsize=(10, 6))
sns.heatmap(heatmap_data, annot=df_melted.pivot("Antibiotic Class", "Isolate", "Resistance"), fmt='', cmap="coolwarm", cbar_kws={'label': 'Resistance (R=1, S=0)'})
plt.title("Antibiotic Resistance Profile of A. baumannii Isolates")
plt.xlabel("Isolate")
plt.ylabel("Antibiotic Class")
plt.xticks(rotation=45)
plt.yticks(rotation=0)
plt.tight_layout()
plt.show()
